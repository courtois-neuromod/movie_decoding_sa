# %%
import warnings
warnings.filterwarnings('ignore')

from report import analysis

# %% [markdown]
# # export MKL_NUM_THREADS=30

# %%
analysis("sana1", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 56.163
#
# Parallel CPU time (seconds):
# 2.900
#
# Makes span (seconds):
# 2.900
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.000
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.007
# ...

# %%
analysis("sana2", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 412.713
#
# Parallel CPU time (seconds):
# 17.391
#
# Makes span (seconds):
# 17.391
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.016
# ...

# %% [markdown]
# # export OMP_NUM_THREADS=30

# %%
analysis("sana3", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 61.526
#
# Parallel CPU time (seconds):
# 4.590
#
# Makes span (seconds):
# 4.590
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %%
analysis("sana4", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 469.314
#
# Parallel CPU time (seconds):
# 17.890
#
# Makes span (seconds):
# 17.890
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.016
# ...

# %%
#https://github.com/xianyi/OpenBLAS

# %% [markdown]
# # export OPENBLAS_NUM_THREADS=30

# %%
analysis("sana5", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 69.267
#
# Parallel CPU time (seconds):
# 4.086
#
# Makes span (seconds):
# 4.086
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.008
# ...

# %%
analysis("sana6", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 475.177
#
# Parallel CPU time (seconds):
# 17.290
#
# Makes span (seconds):
# 17.290
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.000
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.014
# ...

# %% [markdown]
# # export GOTO_NUM_THREADS=30

# %%
analysis("S4_P9_2/sana1", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 69.362
#
# Parallel CPU time (seconds):
# 4.390
#
# Makes span (seconds):
# 4.390
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.008
# ...

# %%
analysis("S4_P9_2/sana2", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 490.394
#
# Parallel CPU time (seconds):
# 18.391
#
# Makes span (seconds):
# 18.391
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.001
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.015
# ...

# %%
analysis("S4_P9_2/sana3", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 66.276
#
# Parallel CPU time (seconds):
# 3.790
#
# Makes span (seconds):
# 3.790
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.000
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.007
# ...

# %%
analysis("S4_P9_2/sana4", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 453.217
#
# Parallel CPU time (seconds):
# 17.290
#
# Makes span (seconds):
# 17.290
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.001
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.015
# ...

# %%
analysis("S4_P9_2/sana5", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 71.038
#
# Parallel CPU time (seconds):
# 3.790
#
# Makes span (seconds):
# 3.790
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.000
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.007
# ...

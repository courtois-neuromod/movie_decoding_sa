# %%
import warnings
warnings.filterwarnings('ignore')

from report import analysis

# %% [markdown]
# # default setting

# %%
#analysis("example-data/cpu")
analysis("sana1", skiprows=15)
#analysis("data-3bb4e2af-bf0a-4b78-b8b2-f9dbd1df35b3 (copy)/cpu")
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 87.605
#
# Parallel CPU time (seconds):
# 4.992
#
# Makes span (seconds):
# 4.992
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.005
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %% [markdown]
# # export MKL_NUM_THREADS=1

# %%
analysis("sana2", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 28.040
#
# Parallel CPU time (seconds):
# 8.491
#
# Makes span (seconds):
# 8.491
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.008
# ...

# %% [markdown]
# # export MKL_NUM_THREADS=4

# %%
analysis("sana3", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 35.390
#
# Parallel CPU time (seconds):
# 5.800
#
# Makes span (seconds):
# 5.800
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %% [markdown]
# #  export NUMEXPR_NUM_THREADS=1

# %%
analysis("sana4", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 74.446
#
# Parallel CPU time (seconds):
# 4.500
#
# Makes span (seconds):
# 4.500
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %% [markdown]
# #  export NUMEXPR_NUM_THREADS=4

# %%
analysis("sana5", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 77.111
#
# Parallel CPU time (seconds):
# 4.490
#
# Makes span (seconds):
# 4.490
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %% [markdown]
# # export OMP_NUM_THREADS=1

# %%
analysis("sana6", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 16.119
#
# Parallel CPU time (seconds):
# 8.900
#
# Makes span (seconds):
# 8.900
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %% [markdown]
# # export OMP_NUM_THREADS=4

# %%
analysis("sana7", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 23.351
#
# Parallel CPU time (seconds):
# 5.200
#
# Makes span (seconds):
# 5.200
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %%
#https://github.com/xianyi/OpenBLAS

# %% [markdown]
# # export OPENBLAS_NUM_THREADS=1

# %%
analysis("sana8", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 64.194
#
# Parallel CPU time (seconds):
# 4.690
#
# Makes span (seconds):
# 4.690
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %% [markdown]
# # export OPENBLAS_NUM_THREADS=4

# %%
analysis("sana9", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 67.525
#
# Parallel CPU time (seconds):
# 4.991
#
# Makes span (seconds):
# 4.991
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...

# %% [markdown]
# # export GOTO_NUM_THREADS=1

# %%
analysis("sana10", skiprows=15)
# Out:
# ...
#     CPU Analysis
# ...
# Total CPU core:
# 64
#
# Total CPU time (seconds):
# 73.756
#
# Parallel CPU time (seconds):
# 4.891
#
# Makes span (seconds):
# 4.891
# ...
#     Disk I/O
# ...
# Data transfer (Gb):
# Read:
# [DSK:sdf]RGBytes    0.000
# [DSK:sdc]RGBytes    0.000
# [DSK:sda]RGBytes    0.000
# [DSK:sde]RGBytes    0.000
# [DSK:sdb]RGBytes    0.000
# [DSK:sdd]RGBytes    0.000
# [DSK:dm-0]RGBytes   0.000
# [DSK:dm-1]RGBytes   0.000
# [DSK:dm-2]RGBytes   0.000
#
# Write:
# [DSK:sdf]WGBytes    0.000
# [DSK:sdc]WGBytes    0.000
# [DSK:sda]WGBytes    0.000
# [DSK:sde]WGBytes    0.000
# [DSK:sdb]WGBytes    0.000
# [DSK:sdd]WGBytes    0.000
# [DSK:dm-0]WGBytes   0.000
# [DSK:dm-1]WGBytes   0.000
# [DSK:dm-2]WGBytes   0.000
#
# Total: 0.000
#
# Total I/O time (seconds):
# 0.000
#
# Parallel I/O time (seconds):
# 0.000
# ...
#     Network I/O
# ...
# Data transfer (Gb):
# Read:
# [NET:ens4f0]RxGB   0.002
# [NET:lo]RxGB       0.000
# [NET:ens4f1]RxGB   0.000
#
# Write:
# [NET:ens4f0]TxGB   0.009
# ...
